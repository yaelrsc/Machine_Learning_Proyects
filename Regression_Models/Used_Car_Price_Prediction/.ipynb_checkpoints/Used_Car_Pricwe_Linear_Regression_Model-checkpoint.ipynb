# %%
import pandas as pd
import numpy as np
from Machine_Learning_Tools.plots import *
from Machine_Learning_Tools.Neural_Networks_Models import single_layer_perceptron,set_random_seed
from sklearn.preprocessing import OneHotEncoder,RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
import tensorflow.keras as kr
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import pickle
warnings.filterwarnings("ignore")
sns.set_theme(context='notebook',style='whitegrid',palette='dark',font_scale=1.0)
# %matplotlib inline

# %%
X_train = pd.read_csv('datasets/X_train.csv')
y_train = pd.read_csv('datasets/y_train.csv')

X_test = pd.read_csv('datasets/X_test.csv')
y_test = pd.read_csv('datasets/test_label/y_test.csv')

df = X_train.merge(y_train)

# %%
X_train.head()
# Out:
#    carID     brand      model  year transmission  mileage fuelType    tax  \
# 0  13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1  17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2  12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3  13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4  16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
#
#     mpg  engineSize
# 0  39.8         2.2
# 1  60.1         2.0
# 2  29.1         2.9
# 3  57.6         2.0
# 4  47.1         1.0

# %%
df = df.drop('carID',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4960 entries, 0 to 4959
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4960 non-null   object
#  1   model         4960 non-null   object
#  2   year          4960 non-null   int64
#  3   transmission  4960 non-null   object
#  4   mileage       4960 non-null   int64
#  5   fuelType      4960 non-null   object
#  6   tax           4960 non-null   float64
#  7   mpg           4960 non-null   float64
#  8   engineSize    4960 non-null   float64
#  9   price         4960 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 426.2+ KB

# %%
categorical_features = df.columns[df.dtypes=='object']
numeric_features = df.columns[df.dtypes!='object']

# %%
barplot1(df,categorical_features,figsize=(16,10))

# %%
pairplot(df,numeric_features)

# %%
correlogram(df,numeric_features,figsize=(16,8))

# %%
sns.histplot(df,x='price')
plt.ylabel('')
plt.show()

# %%
most_freq_models = list(X_train.groupby('model').count().query('year>=100').index)

def model_car_transform(df):
    
    for i in range(df.shape[0]):
        
        model = df['model'].iloc[i]
        
        if most_freq_models.count(model)==0:
            
            df['model'].iloc[i] = 'other'
            
    return df

# %%
X_train = model_car_transform(X_train)
X_test = model_car_transform(X_test)

# %%
X_train = X_train.drop('carID',axis=1)
X_train.insert(0,'years',X_train['year'].max()-X_train['year'])

X_test = X_test.drop('carID',axis=1)
X_test.insert(0,'years',X_train['year'].max()-X_test['year'])

# %%
X_train = X_train.drop('year',axis=1)
X_test = X_test.drop('year',axis=1)

# %%
numeric_features = X_train.columns[X_train.dtypes!='object']

# %%
num_scaler = RobustScaler()
cat_encoder = OneHotEncoder(drop='first',sparse=False)

features_transformer = ColumnTransformer([
    ('numeric',num_scaler,numeric_features),
    ('categorical',cat_encoder,categorical_features)
])

# %%
features_transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('numeric', RobustScaler(),
#                                  Index(['years', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')),
#                                 ('categorical',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  Index(['brand', 'model', 'transmission', 'fuelType'], dtype='object'))])

# %%
X_train_t = features_transformer.transform(X_train)
X_test_t = features_transformer.transform(X_test)

# %%
pca = PCA()

# %%
pca.fit(X_train_t)
# Out:
# PCA()

# %%
variance_ratio_cum = pd.DataFrame({'Variance_Ratio':pca.explained_variance_ratio_.cumsum(),
                                  'Principal_Components':pca.get_feature_names_out()})

sns.barplot(data=variance_ratio_cum.iloc[:10,:],y='Variance_Ratio',x='Principal_Components')
plt.show()

# %%
X_train_pca = pca.transform(X_train_t)[:,:10]
X_test_pca = pca.transform(X_test_t)[:,:10]

y_train_log= np.log(y_train.price.values.reshape(-1,1))
y_test_log= np.log(y_test.price.values.reshape(-1,1))

# %%
def linear_model(lr=0.05,activation='relu'):
    
    input_shape = X_train_pca.shape[1]
    
    n_outputs = 1
    
    optimizer = kr.optimizers.SGD(lr)
    
    loss = kr.losses.MeanSquaredError()
    
    
    model = single_layer_perceptron(input_shape,n_outputs,optimizer,loss,activation=activation)
    
    return model

# %%
set_random_seed(1)
model = linear_model(lr=0.001,activation='linear')
history = model.fit(X_train_pca,y_train_log,epochs=100,validation_data=(X_test_pca,y_test_log))
# Out:
# Epoch 1/100
# 155/155 [==============================] - 2s 2ms/step - loss: 75.9126 - val_loss: 54.7119
# Epoch 2/100
# 155/155 [==============================] - 0s 2ms/step - loss: 40.2846 - val_loss: 29.0678
# Epoch 3/100
# 155/155 [==============================] - 0s 2ms/step - loss: 21.7497 - val_loss: 16.1152
# Epoch 4/100
# 155/155 [==============================] - 0s 2ms/step - loss: 11.8985 - val_loss: 8.5563
# Epoch 5/100
# 155/155 [==============================] - 0s 2ms/step - loss: 6.4853 - val_loss: 4.9449
# Epoch 6/100
# 155/155 [==============================] - 0s 2ms/step - loss: 3.5974 - val_loss: 2.6867
# Epoch 7/100
# 155/155 [==============================] - 0s 2ms/step - loss: 2.0224 - val_loss: 1.5371
# Epoch 8/100
# 155/155 [==============================] - 0s 2ms/step - loss: 1.1800 - val_loss: 0.9135
# Epoch 9/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.7194 - val_loss: 0.5733
# Epoch 10/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.4567 - val_loss: 0.3980
# Epoch 11/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.3183 - val_loss: 0.2821
# Epoch 12/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.2357 - val_loss: 0.2203
# Epoch 13/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1861 - val_loss: 0.1835
# Epoch 14/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1569 - val_loss: 0.1607
# Epoch 15/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1392 - val_loss: 0.1485
# Epoch 16/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1264 - val_loss: 0.1350
# Epoch 17/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1170 - val_loss: 0.1280
# Epoch 18/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1103 - val_loss: 0.1233
# Epoch 19/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1051 - val_loss: 0.1150
# Epoch 20/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.1010 - val_loss: 0.1101
# Epoch 21/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0968 - val_loss: 0.1064
# Epoch 22/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0937 - val_loss: 0.1066
# Epoch 23/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0905 - val_loss: 0.1056
# Epoch 24/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0887 - val_loss: 0.1043
# Epoch 25/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0859 - val_loss: 0.0964
# Epoch 26/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0850 - val_loss: 0.0974
# Epoch 27/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0840 - val_loss: 0.0935
# Epoch 28/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0830 - val_loss: 0.0916
# Epoch 29/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0803 - val_loss: 0.0915
# Epoch 30/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0790 - val_loss: 0.0904
# Epoch 31/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0781 - val_loss: 0.0895
# Epoch 32/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0772 - val_loss: 0.0883
# Epoch 33/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0762 - val_loss: 0.0903
# Epoch 34/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0761 - val_loss: 0.0904
# Epoch 35/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0748 - val_loss: 0.0855
# Epoch 36/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0747 - val_loss: 0.0856
# Epoch 37/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0747 - val_loss: 0.0842
# Epoch 38/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0740 - val_loss: 0.0843
# Epoch 39/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0746 - val_loss: 0.0836
# Epoch 40/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0830
# Epoch 41/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0733 - val_loss: 0.0860
# Epoch 42/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0722 - val_loss: 0.0850
# Epoch 43/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0725 - val_loss: 0.0833
# Epoch 44/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0720 - val_loss: 0.0819
# Epoch 45/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0830
# Epoch 46/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0718 - val_loss: 0.0825
# Epoch 47/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0812
# Epoch 48/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0714 - val_loss: 0.0811
# Epoch 49/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0711 - val_loss: 0.0821
# Epoch 50/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0808
# Epoch 51/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0813
# Epoch 52/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0717 - val_loss: 0.0806
# Epoch 53/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0809
# Epoch 54/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0704 - val_loss: 0.0808
# Epoch 55/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0709 - val_loss: 0.0850
# Epoch 56/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0705 - val_loss: 0.0807
# Epoch 57/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0699 - val_loss: 0.0868
# Epoch 58/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0706 - val_loss: 0.0825
# Epoch 59/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0708 - val_loss: 0.0807
# Epoch 60/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0702 - val_loss: 0.0802
# Epoch 61/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0711 - val_loss: 0.0809
# Epoch 62/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0703 - val_loss: 0.0803
# Epoch 63/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0698 - val_loss: 0.0841
# Epoch 64/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0702 - val_loss: 0.0799
# Epoch 65/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0800
# Epoch 66/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0692 - val_loss: 0.0810
# Epoch 67/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0700 - val_loss: 0.0814
# Epoch 68/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0701 - val_loss: 0.0839
# Epoch 69/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0700 - val_loss: 0.0800
# Epoch 70/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0706 - val_loss: 0.0874
# Epoch 71/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.0834
# Epoch 72/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.0812
# Epoch 73/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0697 - val_loss: 0.0813
# Epoch 74/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0709 - val_loss: 0.0804
# Epoch 75/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0702 - val_loss: 0.0822
# Epoch 76/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0701 - val_loss: 0.0807
# Epoch 77/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0697 - val_loss: 0.0800
# Epoch 78/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0703 - val_loss: 0.0797
# Epoch 79/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0699 - val_loss: 0.0801
# Epoch 80/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0704 - val_loss: 0.0828
# Epoch 81/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0706 - val_loss: 0.0810
# Epoch 82/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0694 - val_loss: 0.0849
# Epoch 83/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0693 - val_loss: 0.0887
# Epoch 84/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0711 - val_loss: 0.0829
# Epoch 85/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0699 - val_loss: 0.0801
# Epoch 86/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0702 - val_loss: 0.0811
# Epoch 87/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0704 - val_loss: 0.0818
# Epoch 88/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0703 - val_loss: 0.0817
# Epoch 89/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0707 - val_loss: 0.0947
# Epoch 90/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0702 - val_loss: 0.0797
# Epoch 91/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0700 - val_loss: 0.0797
# Epoch 92/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.0814
# Epoch 93/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0704 - val_loss: 0.0814
# Epoch 94/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0700 - val_loss: 0.0835
# Epoch 95/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0706 - val_loss: 0.0802
# Epoch 96/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0707 - val_loss: 0.0895
# Epoch 97/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.0799
# Epoch 98/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0697 - val_loss: 0.0797
# Epoch 99/100
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.0834
# Epoch 100/100
# 155/155 [==============================] - 0s 3ms/step - loss: 0.0699 - val_loss: 0.0797

# %%
pd.DataFrame(history.history).plot(figsize=(16,10))
plt.legend(fontsize='large')
plt.show()

# %%
model.save('used_car_price_model.h5')

# %%
pickle.dump(most_freq_models, open('most_freq_models', 'wb'))

# %%
pickle.dump([features_transformer,pca], open('preprocessing_data', 'wb'))

# %%
X_train.brand.unique()
# Out:
# array(['hyundi', 'vauxhall', 'audi', 'vw', 'skoda', 'merc', 'toyota',
#        'bmw', 'ford'], dtype=object)

# %%
features_transformer.feature_names_in_
# Out:
# array(['years', 'brand', 'model', 'transmission', 'mileage', 'fuelType',
#        'tax', 'mpg', 'engineSize'], dtype=object)

# %%
X_train.iloc[0,:].values
# Out:
# array([1, 'hyundi', ' Santa Fe', 'Semi-Auto', 4223, 'Diesel', 145.0, 39.8,
#        2.2], dtype=object)

# %%
pd.DataFrame(X_train.iloc[1:2,:].values,columns=X_train.columns)
# Out:
#   years     brand  model transmission mileage fuelType    tax   mpg engineSize
# 0     5  vauxhall  other       Manual   47870   Diesel  125.0  60.1        2.0

# %%
X_train.iloc[0,:]
# Out:
# years                   1
# brand              hyundi
# model            Santa Fe
# transmission    Semi-Auto
# mileage              4223
# fuelType           Diesel
# tax                 145.0
# mpg                  39.8
# engineSize            2.2
# Name: 0, dtype: object
